# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.load('zip.test-MNIST.data.gz.npy')

# %%
d = data[1].reshape((28,28))

# %%
plt.imshow(d, cmap=plt.cm.gray,)
